# %%
linespace = "="*60

# %% [markdown]
# # Python Fundamentals:
# 1) Installation and Setup
# 2) Variables and Data types
# 3) Basic Operataions and types
# 4) print(), input(), type()
# 5) Strings, and String methods
#
# ## What is Python?
#      1) Python is dynamically typed programming language. It is a high level Language supports Object Oriented Programming.
#      2) It is invented by Guido Van Rossum in 1991 and it is designed as begineer friendly just like learning English.
#      3) It is interpreted language and it is open source.
#
# ## Applications:
#      1) Aritificial Intelligence.
#      2) Web Development.
#      3) Data Science and Analytics.
#      4) Machine Learning.
#      5) Deep Learning.
#      6) Automation and Scripting.

# %% [markdown]
# ## Data Types:
# 1) Primitive Data types - Integer, Float, Complex, Boolean.
# 2) Non-primitive Data-types - List, Dictionary, String, Tuples, Set, Frozen set.

# %%
a = float(input("Enter a number: "))
print(a)
print(type(a))
# Out:
# 2.96
# <class 'float'>

# %% [markdown]
# # Operators:
# 1) Arithmetic - Addition, Subraction, Multplication, Division, Exponential, Modulus.
# 2) Logical - and , or, not
# 3) Bitwise - &, |, ~, ^, <<, >>.
# 4) Relational - <, <=, >, >=, ==, !=
# 5) Assignment -  =, +=, -=,
# 6) Identical - is, not is
# 7) Membership - in , not in

# %%
a = 1
b = 2
print(a+b)
print(linespace)
print(a-b)
print(linespace)
print(a*b)
print(linespace)
print(a/b)
print(linespace)
print(a//b)
print(linespace)
print(a%b)
print(linespace)
print(a%b)
# Out:
# 3
# ...
# -1
# ...
# 2
# ...
# 0.5
# ...
# 0
# ...
# 1
# ...
# 1

# %%
a = 11
b = 2
print(a/b)
print(linespace)
print(a//b)
print()
# Out:
# 5.5
# ...
# 5

# %%
print(a ** b)
# Out:
# 121

# %%
print(a % b)
# Out:
# 1
